# %% [markdown]
# # Lab 3: Практичні завдання — Pandas + API
#
# Виконайте завдання нижче, використовуючи знання з `lab_api_work.ipynb`.

# %%
import pandas as pd
import requests
import json
import os
from datetime import datetime

# %% [markdown]
# ### Завдання 1
# Отримайте всі 100 постів з `https://jsonplaceholder.typicode.com/posts` і створіть DataFrame.

# %%
# Ваш код

# %% [markdown]
# ### Завдання 2
# Отримайте користувачів з `/users` і розгорніть вкладений JSON через `pd.json_normalize()`. Залиште поля: id, name, email, address.city, company.name.

# %%
# Ваш код

# %% [markdown]
# ### Завдання 3
# Напишіть функцію `fetch_with_pagination()` для збору всіх коментарів з `/comments` (500 записів, по 100 на сторінку). Поверніть DataFrame.

# %%
# Ваш код

# %% [markdown]
# ### Завдання 4
# Використайте `https://api.nationalize.io?name=...` для 5 імен на ваш вибір. Розгорніть масив `country` через `pd.json_normalize()` з `record_path` і `meta`.

# %%
# Ваш код

# %% [markdown]
# ### Завдання 5 (ETL)
# Напишіть ETL-пайплайн:
# - **Extract**: отримайте `todos` з JSONPlaceholder
# - **Transform**: залиште тільки `completed=True`, додайте колонку `etl_date`
# - **Load**: збережіть у файли CSV, JSON, Parquet

# %%
# Ваш код

# %% [markdown]
# ### Завдання 6
# Об'єднайте пости з коментарями: отримайте `/posts` і `/comments`, згрупуйте коментарі по `postId`, додайте як нову колонку `comment_count` до постів. Виведіть топ-5 постів за кількістю коментарів.

# %%
# Ваш код

# %% [markdown]
# ### Завдання 7 (Бонус)
# Використайте GitHub API (`https://api.github.com/repos/pandas-dev/pandas/issues?state=all&per_page=100`) з пагінацією. Зберіть всі сторінки (максимум 5). Порахуйте скільки open і closed issues.

# %%
# Ваш код
