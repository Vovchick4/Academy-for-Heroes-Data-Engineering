# %% [markdown]
# # Lab 2: Практичні завдання — Pandas + Бази даних
#
# Виконайте завдання нижче, використовуючи знання з `lab_db_work.ipynb`.

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, text, inspect

engine = create_engine('sqlite:///:memory:', echo=False)

# %% [markdown]
# ### Завдання 1
# Створіть таблицю `orders` з колонками: order_id, customer_name, product, quantity, price, order_date. Додайте 10 замовлень.

# %%
# Ваш код

# %% [markdown]
# ### Завдання 2
# Прочитайте всі замовлення з ціною > 100 через `pd.read_sql()`

# %%
# Ваш код

# %% [markdown]
# ### Завдання 3
# Використайте параметризований запит: знайдіть замовлення клієнта `customer_name` (змінна) з quantity > 2.

# %%
# Ваш код

# %% [markdown]
# ### Завдання 4
# Створіть DataFrame `new_orders` (3 замовлення) і додайте (`append`) їх у таблицю `orders` через `to_sql()`

# %%
# Ваш код

# %% [markdown]
# ### Завдання 5
# Зробіть SQL-запит з GROUP BY: загальна сума продажів (`SUM(price * quantity)`) по кожному продукту. Виконайте агрегацію на стороні БД.

# %%
# Ваш код

# %% [markdown]
# ### Завдання 6
# Створіть другу таблицю `customers` (customer_id, name, city, registration_date). Зробіть ETL:
# - Extract: прочитайте обидві таблиці
# - Transform: об'єднайте через merge, додайте колонку `total_spent`
# - Load: збережіть результат у нову таблицю `customer_analytics`

# %%
# Ваш код

# %% [markdown]
# ### Завдання 7 (Бонус)
# Якщо маєте PostgreSQL/MySQL — підключіться до своєї бази, прочитайте таблицю, зробіть трансформацію і запишіть назад.

# %%
# Ваш код
